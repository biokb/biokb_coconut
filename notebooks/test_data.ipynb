# %%
import pandas as pd
from sqlalchemy import create_engine

engine = create_engine("mysql+pymysql://biokb_user:biokb_passwd@127.0.0.1:3307/biokb")

# %%
df0 = pd.read_csv(
    "/home/ceb/.biokb/coconut/data/coconut_csv-07-2025.csv",
    low_memory=False,
    usecols=["synonyms"],
)
df0.index = df0.index + 1  # Adjust index to start from 1

# %%
df = df0.synonyms.dropna().str.split("|").explode().to_frame()

# %%
df_unique = pd.DataFrame(df.iloc[:, 0].unique(), columns=["name"])
df_unique.index += 1  # Start index from 1
df_unique.head()
# Out:
#                   name
# 1  4'-Deoxydoxorubicin
# 2           63521-85-7
# 3       Esorubicin INN
# 4   4'-Deoxyadriamycin
# 5           RMC41L2WQ3

# %%
df_unique[df_unique.name == "3R"]
# Out:
#     name
# 428   3R

# %%
df_unique.to_sql(
    "coconut_synonym",
    con=engine,
    if_exists="append",
    index=True,
    index_label="id",
)
# Out:
# ---------------------------------------------------------------------------
# IntegrityError                            Traceback (most recent call last)
# File ~/workspace/github/biokb/biokb_coconut/.venv/lib/python3.12/site-packages/sqlalchemy/engine/base.py:1932, in Connection._exec_single_context(self, dialect, context, statement, parameters)
#    1931     if not evt_handled:
# -> 1932         self.dialect.do_executemany(
#    1933             cursor,
#    1934             str_statement,
#    1935             effective_parameters,
#    1936             context,
#    1937         )
#    1938 elif not effective_parameters and context.no_parameters:
#
# File ~/workspace/github/biokb/biokb_coconut/.venv/lib/python3.12/site-packages/sqlalchemy/dialects/mysql/mysqldb.py:172, in MySQLDialect_mysqldb.do_executemany(self, cursor, statement, parameters, context)
#     171 def do_executemany(self, cursor, statement, parameters, context=None):
# ...
