# %%
from biokb_coconut.db.manager import DbManager
from biokb_coconut.db import models
import pandas as pd

# %%
dbm = DbManager()
df = dbm.import_data()
# Out:
# INFO:biokb_coconut.db.manager:Engine Engine(sqlite:////home/ceb/.biokb/biokb.db)
# INFO:biokb_coconut.db.manager:Database dropped
# INFO:biokb_coconut.db.manager:Database created with tables: dict_keys(['coconut_compound_organism', 'coconut_compound_collection', 'coconut_compound_synonym', 'coconut_compound_cas', 'coconut_compound_doi', 'coconut_compound', 'coconut_doi', 'coconut_synonym', 'coconut_organism', 'coconut_collection', 'coconut_cas'])
# INFO:biokb_coconut.db.manager:Importing data from /home/ceb/.biokb/coconut/data/coconut_csv-07-2025.zip
# INFO:biokb_coconut.db.manager:Data imported into coconut_compound
# INFO:biokb_coconut.db.manager:Imported coconut_compound_collection
# INFO:biokb_coconut.db.manager:Imported coconut_compound_organism
# INFO:biokb_coconut.db.manager:Imported coconut_compound_doi
# INFO:biokb_coconut.db.manager:Imported coconut_compound_synonym
# INFO:biokb_coconut.db.manager:Imported coconut_compound_cas
